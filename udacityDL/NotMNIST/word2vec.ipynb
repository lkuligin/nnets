# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                                                     biases=softmax_biases, 
                                                     inputs=embed,
                                                     labels=train_labels, 
                                                     num_sampled=num_sampled, 
                                                     num_classes=vocabulary_size))

    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))


num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.260574
# Nearest to i: crispus, semites, rescues, adjustable, ecstasy, motionless, sloane, manichean,
# Nearest to three: negotiator, propriety, strife, ankles, blanton, writeups, anteater, trimmed,
# Nearest to UNK: khayy, aberdare, maneuverable, valium, zodiacal, expectations, pao, know,
# Nearest to to: fluoxetine, scarcely, breakbeats, ernesto, lambda, army, prepubescent, kinross,
# Nearest to which: dagestan, carpenters, jed, pleistocene, impede, groundwater, stewardship, incomprehensible,
# Nearest to all: monetarism, abbot, straps, interquartile, audiovisual, tammy, oldfield, bosons,
# Nearest to state: braintree, discontinuities, woodward, anaheim, polypeptides, kamehameha, undoubtedly, outline,
# Nearest to system: calamity, shards, pharyngeal, sidecar, meridian, hostage, madame, buchan,
# Nearest to such: informed, absorptive, reine, diffeomorphic, deprogrammers, confounded, lite, shading,
# Nearest to its: qua, hern, medes, imported, cellos, repositories, grandstand, lla,
# Nearest to can: someday, cavers, mockumentary, spreadsheets, rationalization, saturdays, motorbikes, sanjay,
# Nearest to so: nederland, raspberry, codeine, munition, bua, discography, landlord, scanning,
# Nearest to may: brakes, marathi, diseases, mnp, peshawar, herald, rebels, tishri,
# Nearest to however: exhibitions, locke, liberated, beeching, tobruk, calculating, modest, perutz,
# Nearest to has: morse, joh, marchers, espouses, hyper, cronquist, implemented, fiefdom,
# Nearest to were: temperance, isbn, cygwin, rossini, budgetary, trotskyist, citizens, walls,
# Average loss at step 2000: 4.360158
# Average loss at step 4000: 3.861492
# Average loss at step 6000: 3.791163
# Average loss at step 8000: 3.687444
# Average loss at step 10000: 3.613489
# Nearest to i: sloane, acid, rescues, pleasant, ptolemaic, accelerations, semites, transformers,
# Nearest to three: five, eight, six, seven, four, two, nine, zero,
# Nearest to UNK: unpredictable, nederland, supply, r, miserably, euskal, pao, publicacion,
# Nearest to to: prepubescent, between, not, waring, would, nfl, may, emphasises,
# Nearest to which: it, that, pali, ulyanov, veda, also, this, bcl,
# Nearest to all: interquartile, kato, anarchism, ch, monetarism, some, many, alessandri,
# Nearest to state: braintree, discontinuities, kamehameha, rosette, blackburn, efforts, anaheim, boric,
# Nearest to system: calamity, privatization, sidecar, fansite, clarified, andersonville, shards, tata,
# Nearest to such: well, lite, eurocard, known, ephemerides, watered, diffeomorphic, dualistic,
# Nearest to its: the, their, his, fructose, lla, imported, misogynist, cellos,
# Nearest to can: would, could, may, tiled, someday, saturdays, krugerrand, raleigh,
# Nearest to so: nederland, consultant, raspberry, nl, why, porgy, osamu, codeine,
# Nearest to may: mnp, can, would, herald, to, sweet, counterweight, might,
# Nearest to however: hallucinogenic, beeching, exhibitions, slavs, challenger, pastoral, but, baggage,
# Nearest to has: had, was, have, is, vince, archetypes, demonstrated, commonly,
# Nearest to were: are, was, have, had, calls, outlets, walls, and,
# Average loss at step 12000: 3.607985
# Average loss at step 14000: 3.571443
# Average loss at step 16000: 3.405952
# Average loss at step 18000: 3.455621
# Average loss at step 20000: 3.540150
# Nearest to i: ii, sloane, acid, ninety, iii, ua, they, cn,
# Nearest to three: two, five, four, six, seven, eight, zero, one,
# Nearest to UNK: worried, repetitive, burnt, solids, begining, ductus, publicacion, macias,
# Nearest to to: would, prepubescent, not, can, may, could, will, nfl,
# Nearest to which: this, that, it, also, who, but, and, often,
# Nearest to all: some, many, those, these, hg, ch, kato, coffers,
# Nearest to state: braintree, discontinuities, pubns, shelters, triplets, worrying, bogside, efforts,
# Nearest to system: calamity, forming, shards, andersonville, privatization, grudge, sos, unranked,
# Nearest to such: well, known, lite, destabilize, these, workaround, watered, ephemerides,
# Nearest to its: their, his, the, fructose, this, sveriges, lite, her,
# Nearest to can: would, may, could, will, should, must, might, cannot,
# Nearest to so: nederland, fretboard, why, discography, porgy, gwh, underwater, voltaire,
# Nearest to may: can, would, should, will, could, might, must, to,
# Nearest to however: but, that, slavs, when, challenger, which, before, baggage,
# Nearest to has: had, was, is, have, having, macrae, archetypes, demonstrated,
# Nearest to were: are, was, have, had, calls, been, is, outlets,
# Average loss at step 22000: 3.501164
# Average loss at step 24000: 3.491876
# Average loss at step 26000: 3.484273
# Average loss at step 28000: 3.479402
# Average loss at step 30000: 3.500956
# Nearest to i: ii, iii, we, t, acid, watchmen, sloane, they,
# Nearest to three: five, four, seven, eight, two, six, nine, zero,
# Nearest to UNK: skirmish, cairns, indicators, ductus, paul, titular, unpredictable, kulaks,
# Nearest to to: would, must, will, prepubescent, can, could, may, emphasises,
# Nearest to which: this, that, it, readings, also, who, but, where,
# Nearest to all: some, many, kato, these, interquartile, blob, earthy, both,
# Nearest to state: discontinuities, pubns, shelters, rosette, bogside, hailstones, braintree, sentry,
# Nearest to system: shards, calamity, andersonville, privatization, easter, mudslides, pledges, unranked,
# Nearest to such: well, known, these, ephemerides, some, destabilize, watered, many,
# Nearest to its: their, the, his, her, fructose, lite, behavioral, reflector,
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Nearest to so: nederland, fretboard, why, underwater, mortars, discography, kinetics, diu,
# Nearest to may: can, would, will, could, should, must, might, krugerrand,
# Nearest to however: but, although, while, when, that, though, which, years,
# Nearest to has: had, have, was, is, having, revolutionized, archetypes, gratitude,
# Nearest to were: are, was, have, had, been, those, being, be,
# Average loss at step 32000: 3.502965
# Average loss at step 34000: 3.490414
# Average loss at step 36000: 3.452699
# Average loss at step 38000: 3.298217
# Average loss at step 40000: 3.422741
# Nearest to i: ii, t, we, iii, he, they, you, acid,
# Nearest to three: four, five, two, seven, six, eight, one, nine,
# Nearest to UNK: d, buggery, dr, e, wankel, b, boxing, firenze,
# Nearest to to: will, must, would, could, can, in, prepubescent, boltzmann,
# Nearest to which: that, this, who, where, it, also, often, but,
# Nearest to all: some, both, many, these, every, several, blob, earthy,
# Nearest to state: discontinuities, pubns, shelters, rosette, talladega, hailstones, mayall, bogside,
# Nearest to system: systems, yyyy, calamity, demoscene, annunzio, ponty, reichenbach, koreans,
# Nearest to such: well, known, these, many, some, wisest, dualistic, brit,
# Nearest to its: their, his, her, the, fructose, lite, antwerp, natives,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to so: nederland, why, underwater, fretboard, woodlands, lyricists, less, davidson,
# Nearest to may: can, will, would, should, could, must, might, cannot,
# Nearest to however: but, though, although, that, while, when, costanza, since,
# Nearest to has: had, have, was, revolutionized, is, having, vince, macrae,
# Nearest to were: are, have, was, had, be, been, those, being,
# Average loss at step 42000: 3.438578
# Average loss at step 44000: 3.452720
# Average loss at step 46000: 3.449046
# Average loss at step 48000: 3.356779
# Average loss at step 50000: 3.380156
# Nearest to i: ii, we, you, t, rematch, they, iii, suite,
# Nearest to three: four, seven, six, eight, two, five, nine, zero,
# Nearest to UNK: augustus, theses, fas, paigc, mame, el, injecting, sorel,
# Nearest to to: must, emphasises, could, may, operatic, atheistic, stan, can,
# Nearest to which: that, this, who, also, what, often, readings, where,
# Nearest to all: both, some, every, many, these, blob, interquartile, smallholders,
# Nearest to state: discontinuities, pubns, shelters, excised, talladega, mayall, national, mass,
# Nearest to system: systems, yyyy, calamity, demoscene, pledges, brushing, ponty, fraunhofer,
# Nearest to such: well, these, many, known, wisest, ephemerides, workaround, remastered,
# Nearest to its: their, his, the, her, lite, fructose, candlemas, antwerp,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to so: then, nederland, if, why, thou, underwater, stall, davidson,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to however: but, although, while, though, that, when, where, costanza,
# Nearest to has: had, have, is, was, having, revolutionized, contains, laser,
# Nearest to were: are, was, have, had, be, those, been, being,
# Average loss at step 52000: 3.434526
# Average loss at step 54000: 3.424991
# Average loss at step 56000: 3.436284
# Average loss at step 58000: 3.397953
# Average loss at step 60000: 3.393080
# Nearest to i: we, ii, you, t, they, iii, rematch, acid,
# Nearest to three: five, four, six, eight, seven, two, zero, one,
# Nearest to UNK: marie, ross, napster, mauretania, geist, injecting, now, augustus,
# Nearest to to: not, will, pawn, would, operatic, must, could, for,
# Nearest to which: that, this, what, who, also, usually, it, these,
# Nearest to all: both, some, many, any, various, every, interquartile, these,
# Nearest to state: discontinuities, pubns, shelters, states, mayall, sentry, national, government,
# Nearest to system: systems, yyyy, calamity, demoscene, ponty, vowel, fraunhofer, network,
# Nearest to such: well, known, many, these, wisest, unifying, ephemerides, certain,
# Nearest to its: their, his, the, her, lite, whose, fructose, constructive,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to so: then, nederland, underwater, why, if, too, stall, davidson,
# Nearest to may: can, will, would, should, could, must, might, cannot,
# Nearest to however: but, although, though, that, costanza, when, while, since,
# Nearest to has: had, have, was, having, is, contains, revolutionized, spelled,
# Nearest to were: are, have, was, had, those, been, monogamy, overactive,
# Average loss at step 62000: 3.236990
# Average loss at step 64000: 3.255609
# Average loss at step 66000: 3.408257
# Average loss at step 68000: 3.389413
# Average loss at step 70000: 3.360749
# Nearest to i: ii, we, you, iii, rematch, t, g, log,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to UNK: j, tread, apotheosis, g, nonzero, issas, der, payable,
# Nearest to to: will, must, would, may, could, might, should, can,
# Nearest to which: that, this, also, but, what, usually, however, where,
# Nearest to all: both, some, many, various, any, every, several, tzow,
# Nearest to state: government, discontinuities, pubns, shelters, mayall, lawlessness, excised, sentry,
# Nearest to system: systems, bar, vowel, ips, demoscene, fraunhofer, network, despite,
# Nearest to such: these, well, known, many, wisest, some, certain, unifying,
# Nearest to its: their, his, the, her, whose, lite, tarquin, fructose,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to so: then, nederland, too, underwater, if, thus, why, porgy,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to however: but, though, although, that, while, when, where, costanza,
# Nearest to has: had, have, is, was, since, contains, revolutionized, having,
# Nearest to were: are, was, have, be, had, been, those, became,
# Average loss at step 72000: 3.370635
# Average loss at step 74000: 3.344355
# Average loss at step 76000: 3.311264
# Average loss at step 78000: 3.353414
# Average loss at step 80000: 3.380443
# Nearest to i: ii, we, you, iii, t, suite, g, alarc,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to UNK: smith, jones, r, diagrams, eur, boutros, j, gallifrey,
# Nearest to to: must, could, would, zapatistas, will, shall, can, atheistic,
# Nearest to which: that, this, usually, what, where, also, who, but,
# Nearest to all: both, every, various, many, some, any, tzow, several,
# Nearest to state: government, discontinuities, mayall, states, city, shelters, refounded, excised,
# Nearest to system: systems, structures, ips, ota, shift, bar, despot, vowel,
# Nearest to such: well, these, known, wisest, certain, various, spielberg, remastered,
# Nearest to its: their, his, her, the, your, tarquin, lite, whose,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to so: too, then, nederland, if, when, before, underwater, thus,
# Nearest to may: can, could, might, should, would, must, will, cannot,
# Nearest to however: but, although, that, though, when, while, where, including,
# Nearest to has: had, have, is, since, revolutionized, was, having, although,
# Nearest to were: are, was, have, had, those, became, be, is,
# Average loss at step 82000: 3.407598
# Average loss at step 84000: 3.410121
# Average loss at step 86000: 3.384684
# Average loss at step 88000: 3.351524
# Average loss at step 90000: 3.362502
# Nearest to i: we, you, ii, t, iii, g, v, tarleton,
# Nearest to three: five, four, two, seven, eight, six, zero, nine,
# Nearest to UNK: johnson, worried, pvc, oedipus, loomis, merit, qu, rosenbaum,
# Nearest to to: emphasises, operatic, will, would, towards, raider, must, verdean,
# Nearest to which: that, this, what, usually, also, but, who, these,
# Nearest to all: both, tzow, every, many, various, some, several, those,
# Nearest to state: government, shelters, city, states, discontinuities, national, mayall, sentry,
# Nearest to system: systems, vowel, depraved, network, ota, shift, ips, demoscene,
# Nearest to such: well, known, these, certain, wisest, novak, follows, meritorious,
# Nearest to its: their, his, her, the, your, sveriges, whose, fructose,
# Nearest to can: may, could, will, must, would, might, should, cannot,
# Nearest to so: too, underwater, thus, nederland, tristar, stall, mindfulness, if,
# Nearest to may: can, could, might, should, will, would, must, cannot,
# Nearest to however: but, although, that, though, aggravating, during, while, since,
# Nearest to has: had, have, is, was, having, since, contains, requires,
# Nearest to were: are, had, was, have, while, these, those, although,
# Average loss at step 92000: 3.397104
# Average loss at step 94000: 3.254770
# Average loss at step 96000: 3.357120
# Average loss at step 98000: 3.241597
# Average loss at step 100000: 3.358490
# Nearest to i: we, you, ii, iii, they, t, v, alarc,
# Nearest to three: four, seven, five, six, two, eight, nine, zero,
# Nearest to UNK: metrolink, ductus, iguana, bardeen, lingo, denard, liguria, spokesman,
# Nearest to to: will, would, should, could, must, can, operatic, shall,
# Nearest to which: that, this, what, usually, these, who, but, however,
# Nearest to all: both, every, many, various, tzow, these, some, several,
# Nearest to state: government, shelters, city, states, sentry, refounded, discontinuities, braintree,
# Nearest to system: systems, depraved, network, structure, ota, ips, vowel, froze,
# Nearest to such: known, well, these, certain, many, unifying, wisest, opposed,
# Nearest to its: their, his, her, the, your, whose, fructose, our,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to so: thus, too, underwater, why, stall, nederland, when, then,
# Nearest to may: can, could, should, might, would, must, will, cannot,
# Nearest to however: but, though, although, that, and, which, especially, while,
# Nearest to has: had, have, was, is, since, revolutionized, having, contains,
# Nearest to were: are, have, was, these, had, those, although, while,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Problem

# %%
data_index = 0

def generate_batch(batch_size, skip_window):
    global data_index
    span = 2 * skip_window + 1
    batch = np.ndarray(shape=(batch_size, span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[skip_window]
        batch[i] = [buffer[j] for j in range(span) if j <> skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2, 3]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with skip_window = 3:
#     batch: [['anarchism', 'originated', 'as', 'term', 'of', 'abuse'], ['originated', 'as', 'a', 'of', 'abuse', 'first'], ['as', 'a', 'term', 'abuse', 'first', 'used'], ['a', 'term', 'of', 'first', 'used', 'against'], ['term', 'of', 'abuse', 'used', 'against', 'early'], ['of', 'abuse', 'first', 'against', 'early', 'working'], ['abuse', 'first', 'used', 'early', 'working', 'class'], ['first', 'used', 'against', 'working', 'class', 'radicals']]
#     labels: ['a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 2 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                                                     biases=softmax_biases, 
                                                     inputs=tf.reduce_sum(embed, 1),
                                                     labels=train_labels, 
                                                     num_sampled=num_sampled, 
                                                     num_classes=vocabulary_size))

    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.007896
# Nearest to is: protest, suiko, fh, oops, telescopic, anthropos, roots, panda,
# Nearest to but: couturat, haines, torment, reece, buu, subsided, volker, frantz,
# Nearest to his: aragon, selector, concedes, inxs, sacd, offended, zquez, owing,
# Nearest to nine: balliol, gaff, attitudes, schafer, berth, waldemar, faramir, honshu,
# Nearest to as: antimatter, loses, vel, burgundians, erasure, fpgas, hologram, gifted,
# Nearest to state: earthworm, jamie, cta, simplified, vessels, reached, pallium, ivanhoe,
# Nearest to into: woo, mated, deluge, edits, ulrich, protestantism, dispense, hillery,
# Nearest to when: magisterial, pools, accommodation, meal, stepwise, hbox, burg, disconnected,
# Nearest to up: hynek, jug, tude, calibers, fairfax, eudoxus, fixtures, tsarevich,
# Nearest to one: host, notify, genevieve, russcol, thermals, espouse, conditions, toes,
# Nearest to were: oneness, duress, affirm, disobey, reserved, stalling, anscombe, clan,
# Nearest to system: ciboney, exerts, lightest, enix, unemployment, deuteronomy, turnaround, bleeding,
# Nearest to this: finnic, sharm, falun, chiron, attorneys, deadites, scrooge, pretensions,
# Nearest to at: undergoing, amplifying, lewis, advisable, smilga, lite, kilometre, protested,
# Nearest to only: feldspar, visconti, icrc, waging, annotated, confidently, burghs, donors,
# Nearest to so: referenced, depicted, anastasius, abdali, prem, edsger, evaporate, gifs,
# Average loss at step 2000: 9.043200
# Average loss at step 4000: 5.311271
# Average loss at step 6000: 4.434723
# Average loss at step 8000: 4.386086
# Average loss at step 10000: 4.057191
# Nearest to is: was, are, has, did, became, were, koenig, edifices,
# Nearest to but: however, and, which, eugen, raoul, clavichord, shovel, vehemently,
# Nearest to his: their, its, our, compatibility, my, airman, gaps, thrillers,
# Nearest to nine: seven, eight, six, four, zero, indra, flocks, kilogram,
# Nearest to as: guinea, zh, visualize, infirmities, bazaar, paasikivi, aloe, newer,
# Nearest to state: cta, slippery, city, arxiv, framework, dhimma, cutoff, victory,
# Nearest to into: ale, with, mead, freedom, religious, theodosius, mandarin, mecca,
# Nearest to when: danse, where, chilled, if, ordered, educators, since, receptive,
# Nearest to up: papyrus, mbeki, with, allowed, amun, mead, almost, off,
# Nearest to one: surrendering, browne, earthman, indiana, quechua, gorton, encyclical, enhanced,
# Nearest to were: are, was, had, communicate, is, amiga, wolves, rebounded,
# Nearest to system: ale, freedom, mecca, religion, religious, five, mead, aloe,
# Nearest to this: what, an, another, lbs, slime, sage, lusitanian, rios,
# Nearest to at: mead, into, terminated, phrase, ale, that, etc, religious,
# Nearest to only: fortune, mdf, wuthering, abstention, hazardous, exposure, foothold, neurotransmitter,
# Nearest to so: trios, password, valve, pdg, regards, cats, dynamo, installed,
# Average loss at step 12000: 4.041805
# Average loss at step 14000: 4.047601
# Average loss at step 16000: 4.049195
# Average loss at step 18000: 3.751854
# Average loss at step 20000: 3.378565
# Nearest to is: was, are, became, has, were, philanthropy, means, chimpanzees,
# Nearest to but: though, however, and, exterminate, although, condoms, certainly, summaries,
# Nearest to his: their, its, her, the, our, my, s, airman,
# Nearest to nine: eight, seven, five, zero, four, underside, eleven, janusz,
# Nearest to as: allahabad, emitted, ambassador, gallon, rok, jaynes, tunku, ussr,
# Nearest to state: government, territory, fiefdom, arxiv, cutoff, opener, assisting, dryden,
# Nearest to into: through, from, nsa, down, mated, within, carib, nervousness,
# Nearest to when: if, through, where, before, inelastic, while, for, during,
# Nearest to up: away, them, figueres, back, sindhi, off, prevailing, diplomatic,
# Nearest to one: dedekind, seamus, screenings, neighbourhood, capitalized, elias, clitoridectomy, amps,
# Nearest to were: are, was, is, became, haile, newly, ayrshire, shocking,
# Nearest to system: systems, katsura, propelled, carelessness, moods, dost, curious, torah,
# Nearest to this: it, that, the, which, a, omnipotence, elastic, shooters,
# Nearest to at: before, near, trang, since, until, investor, spanking, during,
# Nearest to only: hazardous, worth, opencyc, rising, watches, gilberts, usually, eubacteria,
# Nearest to so: emptying, not, valve, vater, coerce, failed, narrators, slowed,
# Average loss at step 22000: 3.472931
# Average loss at step 24000: 3.609452
# Average loss at step 26000: 3.580455
# Average loss at step 28000: 3.720459
# Average loss at step 30000: 3.446794
# Nearest to is: was, became, are, has, were, occurs, seems, befall,
# Nearest to but: though, and, haldeman, because, while, until, miscarriages, treehouse,
# Nearest to his: her, their, its, my, the, parse, our, airman,
# Nearest to nine: eight, seven, six, five, zero, mid, late, four,
# Nearest to as: allahabad, whist, toolkit, tunku, typography, vpi, phidias, diskette,
# Nearest to state: government, cutoff, bohemia, prints, territory, land, fiefdom, descend,
# Nearest to into: through, within, from, in, between, wallet, sixteen, mated,
# Nearest to when: where, if, before, because, although, since, matsui, after,
# Nearest to up: off, out, figueres, crimes, down, lessened, diplomatic, amun,
# Nearest to one: two, gown, arrian, tulsa, emile, coups, quechua, screenings,
# Nearest to were: are, was, include, newly, is, being, have, had,
# Nearest to system: systems, sped, network, program, propelled, indicator, company, katsura,
# Nearest to this: it, which, konqueror, that, some, a, the, what,
# Nearest to at: montrose, mead, emitted, ablative, brother, ale, html, beads,
# Nearest to only: worth, alemanni, gda, gilberts, no, thz, dos, hudsucker,
# Nearest to so: fact, helical, gein, usages, amstrad, pursuing, musings, isa,
# Average loss at step 32000: 3.376823
# Average loss at step 34000: 3.347246
# Average loss at step 36000: 3.364018
# Average loss at step 38000: 3.368400
# Average loss at step 40000: 3.328517
# Nearest to is: was, are, became, were, has, includes, does, remains,
# Nearest to but: although, however, while, and, though, see, than, woodsman,
# Nearest to his: her, their, its, your, my, our, remembers, airman,
# Nearest to nine: eight, seven, four, five, six, c, korchnoi, underside,
# Nearest to as: ignores, allahabad, tunku, ossetia, whist, encountering, salad, typography,
# Nearest to state: murrow, lysine, nanjing, register, schmitt, imagination, modernisation, deliberation,
# Nearest to into: through, within, mated, sixteen, hyphae, from, out, under,
# Nearest to when: where, if, before, because, surpluses, synchronicity, although, by,
# Nearest to up: off, out, down, figueres, away, merlin, barrel, hynek,
# Nearest to one: screenings, basingstoke, icaza, stain, three, ahead, xor, xenophon,
# Nearest to were: are, was, is, being, had, newly, became, include,
# Nearest to system: systems, propelled, network, indicator, model, concept, mauritian, shapes,
# Nearest to this: it, what, which, novello, lusitanian, the, each, another,
# Nearest to at: near, around, spanking, endosymbiotic, on, denaturation, circumscribed, chickens,
# Nearest to only: always, alemanni, still, usually, earliest, infer, modernisation, burnt,
# Nearest to so: amstrad, arguing, scholarships, musings, bandanese, pursuing, coerce, suggested,
# Average loss at step 42000: 3.429858
# Average loss at step 44000: 3.378494
# Average loss at step 46000: 3.329844
# Average loss at step 48000: 3.258424
# Average loss at step 50000: 3.240987
# Nearest to is: was, are, makes, became, has, were, remains, becomes,
# Nearest to but: although, though, however, summaries, jousting, infrequently, gnumeric, and,
# Nearest to his: her, their, our, its, your, s, the, drusilla,
# Nearest to nine: four, kg, gill, htm, eight, right, ablative, five,
# Nearest to as: allahabad, lo, ossetia, brassicaceae, whist, jointly, materialistic, partitioning,
# Nearest to state: government, national, deliberation, general, frankly, pinky, studded, register,
# Nearest to into: within, under, then, intercalary, in, four, gigantic, kg,
# Nearest to when: while, if, before, where, in, although, under, because,
# Nearest to up: off, out, back, together, fixtures, amun, wads, decided,
# Nearest to one: htm, nine, emitted, kg, literature, now, four, sh,
# Nearest to were: are, was, being, is, newly, had, have, tremendously,
# Nearest to system: systems, prefect, network, propelled, enco, shapes, widgery, flames,
# Nearest to this: the, every, desu, breakers, now, marrow, which, whose,
# Nearest to at: near, around, during, among, hype, until, investor, shao,
# Nearest to only: worth, until, actually, even, alemanni, currently, still, eloquence,
# Nearest to so: ww, coerce, meatball, gein, streaming, talmadge, woo, tilting,
# Average loss at step 52000: 3.235912
# Average loss at step 54000: 3.197671
# Average loss at step 56000: 3.071911
# Average loss at step 58000: 3.199356
# Average loss at step 60000: 3.137885
# Nearest to is: was, are, remains, has, includes, were, becomes, means,
# Nearest to but: although, and, than, though, however, while, smithers, permeated,
# Nearest to his: her, their, its, our, my, your, s, the,
# Nearest to nine: eight, seven, six, five, zero, late, witches, november,
# Nearest to as: allahabad, whist, thrusting, ignores, ossetia, roundhouse, tunku, partitioning,
# Nearest to state: states, arxiv, brindle, konoe, roswell, bohemia, paradigm, district,
# Nearest to into: through, within, from, towards, under, beyond, mated, carries,
# Nearest to when: if, before, where, because, although, until, unless, after,
# Nearest to up: off, out, back, try, wads, wearable, together, unexplained,
# Nearest to one: quechua, screenings, earthman, surrendering, lubricant, avc, lfheim, gown,
# Nearest to were: are, was, is, have, newly, include, being, mexicana,
# Nearest to system: systems, network, process, concept, printing, curious, structure, company,
# Nearest to this: which, it, the, another, what, a, ghaznavid, an,
# Nearest to at: near, during, around, in, toward, throughout, between, spanking,
# Nearest to only: still, until, thunderbolt, alemanni, just, shooters, jai, agassiz,
# Nearest to so: too, tilting, angiotensin, debuted, compounding, meatball, ww, fact,
# Average loss at step 62000: 3.119296
# Average loss at step 64000: 2.992217
# Average loss at step 66000: 3.200568
# Average loss at step 68000: 3.051666
# Average loss at step 70000: 3.186171
# Nearest to is: was, are, becomes, makes, includes, became, remains, gives,
# Nearest to but: inscriptions, korner, chick, erasmus, ablative, credit, arrangement, however,
# Nearest to his: their, her, its, vf, my, vince, both, jonah,
# Nearest to nine: seven, six, th, births, december, september, kabbalist, october,
# Nearest to as: allahabad, ossetia, like, partitioning, ignores, lo, tunku, jussive,
# Nearest to state: government, bohemia, declaration, arxiv, vatican, prints, pittsburgh, defectors,
# Nearest to into: through, within, towards, across, tending, aardvarks, under, mated,
# Nearest to when: inscriptions, before, gigantic, carol, finally, gill, ablative, credit,
# Nearest to up: off, back, out, amun, wads, down, unexplained, olof,
# Nearest to one: four, htm, inscriptions, kg, circ, ablative, emitted, html,
# Nearest to were: are, was, had, vince, lycos, jacobi, cimmerian, numerous,
# Nearest to system: systems, reforms, glottal, model, otters, concept, sockets, propelled,
# Nearest to this: which, another, it, what, that, soddy, vadim, ethnomusicology,
# Nearest to at: near, during, around, spanking, endosymbiotic, hype, investor, flowered,
# Nearest to only: always, typically, proportionally, still, until, usually, just, bowls,
# Nearest to so: anaerobic, too, tilting, impractical, pence, scriptures, debuted, storefront,
# Average loss at step 72000: 3.030439
# Average loss at step 74000: 2.953582
# Average loss at step 76000: 3.100563
# Average loss at step 78000: 3.073769
# Average loss at step 80000: 2.913337
# Nearest to is: was, pot, clipperton, intercalary, says, psychiatrist, inscriptions, stu,
# Nearest to but: though, however, although, and, see, or, using, congregational,
# Nearest to his: her, their, its, the, my, your, s, our,
# Nearest to nine: eight, seven, six, september, zero, th, recherche, july,
# Nearest to as: allahabad, mich, whist, acrylic, ignores, ossetia, novoselic, salad,
# Nearest to state: government, bohemia, territory, states, arxiv, kingdom, somehow, lance,
# Nearest to into: contract, ale, finally, ablative, gabriel, ales, kg, htm,
# Nearest to when: although, inscriptions, ablative, pot, finally, erasmus, gill, ale,
# Nearest to up: back, off, down, together, out, amun, wads, low,
# Nearest to one: screenings, booklet, capitalized, kusanagi, mural, avc, pagos, earthman,
# Nearest to were: are, was, newly, speculating, include, is, inconsistencies, shortcuts,
# Nearest to system: systems, process, concept, service, reforms, hosts, propelled, model,
# Nearest to this: another, what, which, it, a, fatimids, anasazi, lusitanian,
# Nearest to at: near, during, investor, around, toward, since, hype, throughout,
# Nearest to only: always, honours, lucretia, just, alemanni, fully, simply, shooters,
# Nearest to so: too, fact, helical, arguing, now, depend, gein, anaerobic,
# Average loss at step 82000: 3.001030
# Average loss at step 84000: 2.951009
# Average loss at step 86000: 2.981731
# Average loss at step 88000: 2.979849
# Average loss at step 90000: 2.878001
# Nearest to is: was, are, became, becomes, remains, makes, contains, holds,
# Nearest to but: though, although, however, and, showing, see, because, bernardino,
# Nearest to his: their, her, its, your, my, our, s, the,
# Nearest to nine: eight, seven, six, late, th, four, mid, zero,
# Nearest to as: when, glitter, zaire, fills, vor, zh, tunku, broadcasted,
# Nearest to state: bohemia, station, gallia, statue, owner, tribe, arxiv, eccentricities,
# Nearest to into: through, beyond, down, together, mated, onto, out, within,
# Nearest to when: pot, inscriptions, stu, ablative, circ, egypt, erasmus, das,
# Nearest to up: back, down, off, rise, out, amun, wads, treasured,
# Nearest to one: mg, screenings, seven, two, booklet, wartburg, grandstand, radiocarbon,
# Nearest to were: are, was, is, newly, include, speculating, various, balkh,
# Nearest to system: systems, network, reforms, process, concept, flames, sector, reclamation,
# Nearest to this: desu, which, breakers, stu, vf, egypt, miniseries, rescues,
# Nearest to at: investor, during, around, endosymbiotic, spanking, bu, near, shutter,
# Nearest to only: credit, stu, inscriptions, egypt, channel, emitted, ablative, pot,
# Nearest to so: sometimes, now, arguing, believe, fact, say, if, oscillators,
# Average loss at step 92000: 2.945733
# Average loss at step 94000: 2.947032
# Average loss at step 96000: 2.753680
# Average loss at step 98000: 2.526381
# Average loss at step 100000: 2.775363
# Nearest to is: was, holds, contains, exists, are, became, has, remains,
# Nearest to but: however, although, and, though, while, or, enabling, than,
# Nearest to his: their, her, its, my, our, your, s, whose,
# Nearest to nine: eight, five, six, seven, zero, st, th, three,
# Nearest to as: lo, like, allahabad, agilent, whist, salad, vpi, novoselic,
# Nearest to state: covenant, gallia, eccentricities, hypothetical, cabinet, bounds, government, tribe,
# Nearest to into: through, beyond, across, towards, onto, within, in, from,
# Nearest to when: where, if, although, while, because, unless, before, though,
# Nearest to up: off, down, out, together, back, room, tude, amun,
# Nearest to one: quechua, wim, screenings, cray, hogan, leste, porta, booklet,
# Nearest to were: are, was, speculating, include, had, have, is, conspirator,
# Nearest to system: systems, mode, principle, reasoning, tender, galaxies, showdown, shoghi,
# Nearest to this: which, some, another, it, every, what, any, the,
# Nearest to at: near, during, hype, fliers, throughout, dir, spanking, in,
# Nearest to only: always, first, premierships, clues, next, actually, glucocorticoids, youngest,
# Nearest to so: argue, oscillators, feel, believe, say, astute, cosine, arguing,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
